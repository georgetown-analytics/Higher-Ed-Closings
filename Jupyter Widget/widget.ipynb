# %% [markdown]
# ## Higher Ed Closing

# %% [markdown]
# Enter the University or College name to determine potential for school closing.

# %%
import ipywidgets as widgets
from IPython.display import display

# %%
btn = widgets.Button(description='H.E. Capstone')
display(btn)
def btn_eventhandler(obj):
    print('Hello from the {} group!'.format(obj.description))
btn.on_click(btn_eventhandler)
# Out:
# Button(description='H.E. Capstone', style=ButtonStyle())
